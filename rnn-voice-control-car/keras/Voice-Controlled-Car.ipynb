# %% [markdown]
# #### 1. Imports

# %%
from configparser import ConfigParser
from tqdm import tqdm
import numpy as np
import librosa
import os

from sklearn.model_selection import train_test_split

from keras.losses import categorical_crossentropy
from keras.optimizers import Adadelta
from keras.callbacks import ModelCheckpoint
from keras.models import Model, load_model, Sequential
from keras.layers import Dense, Activation, Dropout, Input, Conv1D
from keras.layers import BatchNormalization, Reshape, LSTM
from keras.optimizers import Adam
from keras.utils import to_categorical

# %% [markdown]
# #### 2. Prepare data

# %%
# instantiate
config = ConfigParser()
    
# parse existing file
config.read('config.ini')

in_data = config.get('section_path', 'in_path')
out_data = config.get('section_path', 'out_path')

Keys = config.get('section_keys', 'Keys')
Keys = Keys.split()

# %%
def wav2mfcc(file_path, mfcclen=65):
    # read file
    wave, sr = librosa.load(file_path, mono=True, sr=None)
    
    # calculate power spectrum of a sound
    mfcc = librosa.feature.mfcc(wave, sr=16000)
    
    # pad if required to get 32 len
    if (mfcclen > mfcc.shape[1]):
        pad_width = mfcclen - mfcc.shape[1]
        mfcc = np.pad(mfcc, pad_width=((0, 0), (0, pad_width)), mode='constant')
    else:
        mfcc = mfcc[:,:mfcclen]
    return mfcc

# %%
for Key in Keys:
    if not os.path.isdir(in_data + Key):
        Keys.remove(Key)
        continue
    # init mfcc
    mfcc_v = []
    wavfiles = [in_data + Key + '/' + wavfile for wavfile in os.listdir(in_data + Key)]
    for wavfile in tqdm(wavfiles, "label - '{}'".format(Key), total=len(wavfiles), unit="files"):
        mfcc_v.append(wav2mfcc(wavfile))
    # save it
    np.save(out_data + Key + '.npy', mfcc_v)
# Out:
# label - 'left': 100%|██████████| 207/207 [00:02<00:00, 93.99files/s]
# label - 'right': 100%|██████████| 208/208 [00:02<00:00, 94.87files/s]
# label - 'stop': 100%|██████████| 181/181 [00:01<00:00, 97.33files/s]
# label - 'go': 100%|██████████| 189/189 [00:01<00:00, 96.18files/s]
# label - 'noise': 100%|██████████| 81/81 [00:00<00:00, 94.74files/s]

# %%
for Key in Keys:
    if not os.path.isdir(in_data + Key):
        Keys.remove(Key)
        continue

Keys_Indx = np.arange(0, len(Keys))

# Lets create X, Y for Test and X, Y for validation
for Idx, Key in enumerate(Keys):
    print(Idx, Key)
    if(Idx == 0):
        X = np.load(out_data + Keys[Idx] + '.npy')
        Y = np.zeros(X.shape[Idx])
    else:
        x = np.load(out_data + Keys[Idx] + '.npy')
        X = np.vstack((X, x))
        Y = np.append(Y, np.full(x.shape[0], fill_value = Idx))
        
    assert X.shape[0] == len(Y)
    
XT, XV, YT, YV = train_test_split(X, Y, test_size= (1 - 0.9), random_state=42, shuffle=True)
# Out:
# 0 left
# 1 right
# 2 stop
# 3 go
# 4 noise

# %%
# create one-hot vectors for YT and YV
YT_HOT = to_categorical(YT)
YV_HOT = to_categorical(YV)

# %% [markdown]
# #### 2. Model

# %%
def model(input_shape):
    """
    Function creating the model's graph in Keras.
    
    Argument:
    input_shape -- shape of the model's input data (using Keras conventions)

    Returns:
    model -- Keras model instance
    """
    
    model = Sequential()
    
    model.add(LSTM(units=128, input_shape=input_shape, return_sequences = True))
    
    model.add(LSTM(units=128, return_sequences = True))
    
    model.add(LSTM(units=20, return_sequences = False))
    
    model.add(Dense(units=len(Keys), activation='softmax'))
    
    return model

# %%
model = model(input_shape = XT.shape[1:])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 20, 128)           99328
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 20, 128)           131584
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 20)                11920
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 105
# =================================================================
# Total params: 242,937
# Trainable params: 242,937
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### 4. Training

# %%
model.compile(loss=categorical_crossentropy,
                  optimizer=Adadelta(),
                  metrics=['accuracy'])

# %%
for t in range(2):
    model.fit(XT, YT_HOT, batch_size=64, epochs=100, verbose=2, validation_data=(XV, YV_HOT))
# Out:
# Train on 779 samples, validate on 87 samples
# Epoch 1/100
#  - 3s - loss: 1.3446 - acc: 0.5250 - val_loss: 1.0624 - val_acc: 0.7126
# Epoch 2/100
#  - 1s - loss: 0.8545 - acc: 0.7599 - val_loss: 0.8734 - val_acc: 0.6437
# Epoch 3/100
#  - 1s - loss: 0.6710 - acc: 0.7843 - val_loss: 0.5861 - val_acc: 0.8046
# Epoch 4/100
#  - 1s - loss: 0.4993 - acc: 0.8460 - val_loss: 0.9861 - val_acc: 0.6897
# Epoch 5/100
#  - 1s - loss: 0.3212 - acc: 0.9127 - val_loss: 0.3661 - val_acc: 0.8736
# Epoch 6/100
#  - 1s - loss: 0.2675 - acc: 0.9191 - val_loss: 0.4381 - val_acc: 0.8391
# Epoch 7/100
#  - 1s - loss: 0.1566 - acc: 0.9615 - val_loss: 0.3583 - val_acc: 0.9080
# Epoch 8/100
#  - 1s - loss: 0.0879 - acc: 0.9807 - val_loss: 1.3441 - val_acc: 0.5632
# Epoch 9/100
#  - 1s - loss: 0.2093 - acc: 0.9435 - val_loss: 0.4208 - val_acc: 0.8621
# Epoch 10/100
#  - 1s - loss: 0.0919 - acc: 0.9820 - val_loss: 0.2805 - val_acc: 0.8966
# Epoch 11/100
#  - 1s - loss: 0.0348 - acc: 0.9974 - val_loss: 0.3480 - val_acc: 0.9080
# Epoch 12/100
#  - 1s - loss: 0.0255 - acc: 0.9974 - val_loss: 0.3289 - val_acc: 0.9080
# Epoch 13/100
#  - 1s - loss: 0.0193 - acc: 0.9987 - val_loss: 0.3050 - val_acc: 0.9195
# Epoch 14/100
#  - 1s - loss: 0.0159 - acc: 0.9987 - val_loss: 0.3202 - val_acc: 0.9195
# Epoch 15/100
#  - 1s - loss: 0.0132 - acc: 0.9987 - val_loss: 0.3330 - val_acc: 0.9195
# Epoch 16/100
#  - 1s - loss: 0.0112 - acc: 0.9987 - val_loss: 0.3348 - val_acc: 0.8966
# Epoch 17/100
#  - 1s - loss: 0.0096 - acc: 0.9987 - val_loss: 0.3482 - val_acc: 0.9080
# Epoch 18/100
#  - 1s - loss: 0.0081 - acc: 1.0000 - val_loss: 0.3698 - val_acc: 0.9080
# Epoch 19/100
#  - 1s - loss: 0.0068 - acc: 1.0000 - val_loss: 0.3837 - val_acc: 0.9080
# Epoch 20/100
#  - 1s - loss: 0.0057 - acc: 1.0000 - val_loss: 0.4476 - val_acc: 0.8966
# Epoch 21/100
#  - 1s - loss: 0.0063 - acc: 1.0000 - val_loss: 0.5683 - val_acc: 0.8506
# Epoch 22/100
#  - 1s - loss: 0.0133 - acc: 0.9974 - val_loss: 0.4174 - val_acc: 0.9080
# Epoch 23/100
#  - 1s - loss: 0.0043 - acc: 1.0000 - val_loss: 0.4596 - val_acc: 0.8966
# Epoch 24/100
#  - 1s - loss: 0.0037 - acc: 1.0000 - val_loss: 0.4423 - val_acc: 0.9080
# Epoch 25/100
#  - 1s - loss: 0.0033 - acc: 1.0000 - val_loss: 0.4484 - val_acc: 0.9080
# Epoch 26/100
#  - 1s - loss: 0.0030 - acc: 1.0000 - val_loss: 0.4465 - val_acc: 0.9080
# Epoch 27/100
#  - 1s - loss: 0.0027 - acc: 1.0000 - val_loss: 0.4530 - val_acc: 0.9080
# Epoch 28/100
#  - 1s - loss: 0.0024 - acc: 1.0000 - val_loss: 0.4692 - val_acc: 0.8966
# Epoch 29/100
#  - 1s - loss: 0.0022 - acc: 1.0000 - val_loss: 0.4648 - val_acc: 0.8966
# Epoch 30/100
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.4646 - val_acc: 0.8966
# Epoch 31/100
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.4814 - val_acc: 0.8966
# Epoch 32/100
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.4923 - val_acc: 0.8851
# Epoch 33/100
#  - 1s - loss: 0.0015 - acc: 1.0000 - val_loss: 0.4839 - val_acc: 0.8851
# Epoch 34/100
#  - 1s - loss: 0.0013 - acc: 1.0000 - val_loss: 0.5142 - val_acc: 0.8851
# Epoch 35/100
#  - 1s - loss: 0.0012 - acc: 1.0000 - val_loss: 0.5092 - val_acc: 0.8851
# Epoch 36/100
#  - 1s - loss: 0.0011 - acc: 1.0000 - val_loss: 0.5088 - val_acc: 0.8851
# Epoch 37/100
#  - 1s - loss: 0.0011 - acc: 1.0000 - val_loss: 0.5165 - val_acc: 0.8851
# Epoch 38/100
#  - 1s - loss: 9.9201e-04 - acc: 1.0000 - val_loss: 0.5259 - val_acc: 0.8851
# Epoch 39/100
#  - 1s - loss: 9.2814e-04 - acc: 1.0000 - val_loss: 0.5135 - val_acc: 0.8851
# Epoch 40/100
#  - 1s - loss: 8.7157e-04 - acc: 1.0000 - val_loss: 0.5074 - val_acc: 0.8966
# Epoch 41/100
#  - 1s - loss: 8.2628e-04 - acc: 1.0000 - val_loss: 0.5256 - val_acc: 0.8851
# Epoch 42/100
#  - 1s - loss: 7.7827e-04 - acc: 1.0000 - val_loss: 0.5291 - val_acc: 0.8851
# Epoch 43/100
#  - 1s - loss: 7.3757e-04 - acc: 1.0000 - val_loss: 0.5249 - val_acc: 0.8851
# Epoch 44/100
#  - 1s - loss: 7.0027e-04 - acc: 1.0000 - val_loss: 0.5219 - val_acc: 0.8851
# Epoch 45/100
#  - 1s - loss: 6.6688e-04 - acc: 1.0000 - val_loss: 0.5253 - val_acc: 0.8851
# Epoch 46/100
#  - 1s - loss: 6.3656e-04 - acc: 1.0000 - val_loss: 0.5279 - val_acc: 0.8851
# Epoch 47/100
#  - 1s - loss: 6.0991e-04 - acc: 1.0000 - val_loss: 0.5244 - val_acc: 0.8851
# Epoch 48/100
#  - 1s - loss: 5.8470e-04 - acc: 1.0000 - val_loss: 0.5275 - val_acc: 0.8851
# Epoch 49/100
#  - 1s - loss: 5.6162e-04 - acc: 1.0000 - val_loss: 0.5314 - val_acc: 0.8851
# Epoch 50/100
#  - 1s - loss: 5.4002e-04 - acc: 1.0000 - val_loss: 0.5309 - val_acc: 0.8851
# Epoch 51/100
#  - 1s - loss: 5.2041e-04 - acc: 1.0000 - val_loss: 0.5393 - val_acc: 0.8851
# Epoch 52/100
#  - 1s - loss: 5.0185e-04 - acc: 1.0000 - val_loss: 0.5468 - val_acc: 0.8851
# Epoch 53/100
#  - 1s - loss: 4.8464e-04 - acc: 1.0000 - val_loss: 0.5380 - val_acc: 0.8851
# Epoch 54/100
#  - 1s - loss: 4.6884e-04 - acc: 1.0000 - val_loss: 0.5465 - val_acc: 0.8851
# Epoch 55/100
#  - 1s - loss: 4.5382e-04 - acc: 1.0000 - val_loss: 0.5523 - val_acc: 0.8851
# Epoch 56/100
#  - 1s - loss: 4.3965e-04 - acc: 1.0000 - val_loss: 0.5551 - val_acc: 0.8851
# Epoch 57/100
#  - 1s - loss: 4.2638e-04 - acc: 1.0000 - val_loss: 0.5574 - val_acc: 0.8851
# Epoch 58/100
#  - 1s - loss: 4.1410e-04 - acc: 1.0000 - val_loss: 0.5551 - val_acc: 0.8851
# Epoch 59/100
#  - 1s - loss: 4.0224e-04 - acc: 1.0000 - val_loss: 0.5579 - val_acc: 0.8851
# Epoch 60/100
#  - 1s - loss: 3.9109e-04 - acc: 1.0000 - val_loss: 0.5636 - val_acc: 0.8851
# Epoch 61/100
#  - 1s - loss: 3.8069e-04 - acc: 1.0000 - val_loss: 0.5664 - val_acc: 0.8851
# Epoch 62/100
#  - 1s - loss: 3.7083e-04 - acc: 1.0000 - val_loss: 0.5609 - val_acc: 0.8851
# Epoch 63/100
#  - 1s - loss: 3.6127e-04 - acc: 1.0000 - val_loss: 0.5689 - val_acc: 0.8851
# Epoch 64/100
#  - 1s - loss: 3.5232e-04 - acc: 1.0000 - val_loss: 0.5710 - val_acc: 0.8851
# Epoch 65/100
#  - 1s - loss: 3.4381e-04 - acc: 1.0000 - val_loss: 0.5608 - val_acc: 0.8851
# Epoch 66/100
#  - 1s - loss: 3.3570e-04 - acc: 1.0000 - val_loss: 0.5732 - val_acc: 0.8851
# Epoch 67/100
#  - 1s - loss: 3.2801e-04 - acc: 1.0000 - val_loss: 0.5782 - val_acc: 0.8736
# Epoch 68/100
#  - 1s - loss: 3.2057e-04 - acc: 1.0000 - val_loss: 0.5756 - val_acc: 0.8736
# Epoch 69/100
#  - 1s - loss: 3.1353e-04 - acc: 1.0000 - val_loss: 0.5802 - val_acc: 0.8851
# Epoch 70/100
#  - 1s - loss: 3.0673e-04 - acc: 1.0000 - val_loss: 0.5807 - val_acc: 0.8851
# Epoch 71/100
#  - 1s - loss: 3.0035e-04 - acc: 1.0000 - val_loss: 0.5804 - val_acc: 0.8851
# Epoch 72/100
#  - 1s - loss: 2.9410e-04 - acc: 1.0000 - val_loss: 0.5797 - val_acc: 0.8851
# Epoch 73/100
#  - 1s - loss: 2.8816e-04 - acc: 1.0000 - val_loss: 0.5613 - val_acc: 0.8736
# Epoch 74/100
#  - 1s - loss: 2.8246e-04 - acc: 1.0000 - val_loss: 0.5904 - val_acc: 0.8736
# Epoch 75/100
#  - 1s - loss: 2.7690e-04 - acc: 1.0000 - val_loss: 0.5891 - val_acc: 0.8736
# Epoch 76/100
#  - 1s - loss: 2.7162e-04 - acc: 1.0000 - val_loss: 0.5918 - val_acc: 0.8736
# Epoch 77/100
#  - 1s - loss: 2.6658e-04 - acc: 1.0000 - val_loss: 0.5909 - val_acc: 0.8736
# Epoch 78/100
#  - 1s - loss: 2.6175e-04 - acc: 1.0000 - val_loss: 0.5669 - val_acc: 0.8736
# Epoch 79/100
#  - 1s - loss: 2.5699e-04 - acc: 1.0000 - val_loss: 0.5953 - val_acc: 0.8736
# Epoch 80/100
#  - 1s - loss: 2.5243e-04 - acc: 1.0000 - val_loss: 0.5944 - val_acc: 0.8736
# Epoch 81/100
#  - 1s - loss: 2.4801e-04 - acc: 1.0000 - val_loss: 0.5983 - val_acc: 0.8736
# Epoch 82/100
#  - 1s - loss: 2.4371e-04 - acc: 1.0000 - val_loss: 0.6000 - val_acc: 0.8736
# Epoch 83/100
#  - 1s - loss: 2.3964e-04 - acc: 1.0000 - val_loss: 0.6010 - val_acc: 0.8736
# Epoch 84/100
#  - 1s - loss: 2.3580e-04 - acc: 1.0000 - val_loss: 0.5978 - val_acc: 0.8736
# Epoch 85/100
#  - 1s - loss: 2.3192e-04 - acc: 1.0000 - val_loss: 0.5845 - val_acc: 0.8736
# Epoch 86/100
#  - 1s - loss: 2.2817e-04 - acc: 1.0000 - val_loss: 0.5854 - val_acc: 0.8736
# Epoch 87/100
#  - 1s - loss: 2.2465e-04 - acc: 1.0000 - val_loss: 0.6043 - val_acc: 0.8736
# Epoch 88/100
#  - 1s - loss: 2.2116e-04 - acc: 1.0000 - val_loss: 0.6078 - val_acc: 0.8736
# Epoch 89/100
#  - 1s - loss: 2.1777e-04 - acc: 1.0000 - val_loss: 0.6068 - val_acc: 0.8736
# Epoch 90/100
#  - 1s - loss: 2.1449e-04 - acc: 1.0000 - val_loss: 0.6050 - val_acc: 0.8736
# Epoch 91/100
#  - 1s - loss: 2.1128e-04 - acc: 1.0000 - val_loss: 0.6028 - val_acc: 0.8736
# Epoch 92/100
#  - 1s - loss: 2.0818e-04 - acc: 1.0000 - val_loss: 0.6063 - val_acc: 0.8736
# Epoch 93/100
#  - 1s - loss: 2.0512e-04 - acc: 1.0000 - val_loss: 0.6060 - val_acc: 0.8736
# Epoch 94/100
#  - 1s - loss: 2.0229e-04 - acc: 1.0000 - val_loss: 0.6128 - val_acc: 0.8736
# Epoch 95/100
#  - 1s - loss: 1.9947e-04 - acc: 1.0000 - val_loss: 0.6124 - val_acc: 0.8736
# Epoch 96/100
#  - 1s - loss: 1.9663e-04 - acc: 1.0000 - val_loss: 0.6118 - val_acc: 0.8736
# Epoch 97/100
#  - 1s - loss: 1.9398e-04 - acc: 1.0000 - val_loss: 0.6126 - val_acc: 0.8736
# Epoch 98/100
#  - 1s - loss: 1.9134e-04 - acc: 1.0000 - val_loss: 0.6133 - val_acc: 0.8736
# Epoch 99/100
#  - 1s - loss: 1.8878e-04 - acc: 1.0000 - val_loss: 0.6148 - val_acc: 0.8736
# Epoch 100/100
#  - 1s - loss: 1.8632e-04 - acc: 1.0000 - val_loss: 0.6143 - val_acc: 0.8736
# Train on 779 samples, validate on 87 samples
# Epoch 1/100
#  - 1s - loss: 1.8391e-04 - acc: 1.0000 - val_loss: 0.6105 - val_acc: 0.8736
# Epoch 2/100
#  - 1s - loss: 1.8151e-04 - acc: 1.0000 - val_loss: 0.6125 - val_acc: 0.8736
# Epoch 3/100
#  - 1s - loss: 1.7933e-04 - acc: 1.0000 - val_loss: 0.6137 - val_acc: 0.8736
# Epoch 4/100
#  - 1s - loss: 1.7709e-04 - acc: 1.0000 - val_loss: 0.6134 - val_acc: 0.8736
# Epoch 5/100
#  - 1s - loss: 1.7491e-04 - acc: 1.0000 - val_loss: 0.6149 - val_acc: 0.8736
# Epoch 6/100
#  - 1s - loss: 1.7279e-04 - acc: 1.0000 - val_loss: 0.6175 - val_acc: 0.8736
# Epoch 7/100
#  - 1s - loss: 1.7071e-04 - acc: 1.0000 - val_loss: 0.6185 - val_acc: 0.8736
# Epoch 8/100
#  - 1s - loss: 1.6869e-04 - acc: 1.0000 - val_loss: 0.6195 - val_acc: 0.8736
# Epoch 9/100
#  - 1s - loss: 1.6673e-04 - acc: 1.0000 - val_loss: 0.6258 - val_acc: 0.8736
# Epoch 10/100
#  - 1s - loss: 1.6479e-04 - acc: 1.0000 - val_loss: 0.6248 - val_acc: 0.8736
# Epoch 11/100
#  - 1s - loss: 1.6290e-04 - acc: 1.0000 - val_loss: 0.6207 - val_acc: 0.8736
# Epoch 12/100
#  - 1s - loss: 1.6106e-04 - acc: 1.0000 - val_loss: 0.6193 - val_acc: 0.8736
# Epoch 13/100
#  - 1s - loss: 1.5921e-04 - acc: 1.0000 - val_loss: 0.6221 - val_acc: 0.8736
# Epoch 14/100
#  - 1s - loss: 1.5743e-04 - acc: 1.0000 - val_loss: 0.6229 - val_acc: 0.8736
# Epoch 15/100
#  - 1s - loss: 1.5571e-04 - acc: 1.0000 - val_loss: 0.6225 - val_acc: 0.8736
# Epoch 16/100
#  - 1s - loss: 1.5411e-04 - acc: 1.0000 - val_loss: 0.6214 - val_acc: 0.8736
# Epoch 17/100
#  - 1s - loss: 1.5244e-04 - acc: 1.0000 - val_loss: 0.6206 - val_acc: 0.8736
# Epoch 18/100
#  - 1s - loss: 1.5082e-04 - acc: 1.0000 - val_loss: 0.6356 - val_acc: 0.8736
# Epoch 19/100
#  - 1s - loss: 1.4925e-04 - acc: 1.0000 - val_loss: 0.6233 - val_acc: 0.8736
# Epoch 20/100
#  - 1s - loss: 1.4768e-04 - acc: 1.0000 - val_loss: 0.6247 - val_acc: 0.8736
# Epoch 21/100
#  - 1s - loss: 1.4617e-04 - acc: 1.0000 - val_loss: 0.6277 - val_acc: 0.8736
# Epoch 22/100
#  - 1s - loss: 1.4468e-04 - acc: 1.0000 - val_loss: 0.6260 - val_acc: 0.8736
# Epoch 23/100
#  - 1s - loss: 1.4323e-04 - acc: 1.0000 - val_loss: 0.6207 - val_acc: 0.8736
# Epoch 24/100
#  - 1s - loss: 1.4181e-04 - acc: 1.0000 - val_loss: 0.6309 - val_acc: 0.8736
# Epoch 25/100
#  - 1s - loss: 1.4040e-04 - acc: 1.0000 - val_loss: 0.6324 - val_acc: 0.8736
# Epoch 26/100
#  - 1s - loss: 1.3904e-04 - acc: 1.0000 - val_loss: 0.6376 - val_acc: 0.8736
# Epoch 27/100
#  - 1s - loss: 1.3769e-04 - acc: 1.0000 - val_loss: 0.6386 - val_acc: 0.8736
# Epoch 28/100
#  - 1s - loss: 1.3637e-04 - acc: 1.0000 - val_loss: 0.6405 - val_acc: 0.8736
# Epoch 29/100
#  - 1s - loss: 1.3509e-04 - acc: 1.0000 - val_loss: 0.6396 - val_acc: 0.8736
# Epoch 30/100
#  - 1s - loss: 1.3381e-04 - acc: 1.0000 - val_loss: 0.6310 - val_acc: 0.8736
# Epoch 31/100
#  - 1s - loss: 1.3255e-04 - acc: 1.0000 - val_loss: 0.6361 - val_acc: 0.8736
# Epoch 32/100
#  - 1s - loss: 1.3133e-04 - acc: 1.0000 - val_loss: 0.6371 - val_acc: 0.8736
# Epoch 33/100
#  - 1s - loss: 1.3013e-04 - acc: 1.0000 - val_loss: 0.6461 - val_acc: 0.8736
# Epoch 34/100
#  - 1s - loss: 1.2897e-04 - acc: 1.0000 - val_loss: 0.6425 - val_acc: 0.8736
# Epoch 35/100
#  - 1s - loss: 1.2780e-04 - acc: 1.0000 - val_loss: 0.6429 - val_acc: 0.8736
# Epoch 36/100
#  - 1s - loss: 1.2666e-04 - acc: 1.0000 - val_loss: 0.6441 - val_acc: 0.8736
# Epoch 37/100
#  - 1s - loss: 1.2556e-04 - acc: 1.0000 - val_loss: 0.6329 - val_acc: 0.8736
# Epoch 38/100
#  - 1s - loss: 1.2447e-04 - acc: 1.0000 - val_loss: 0.6385 - val_acc: 0.8736
# Epoch 39/100
#  - 1s - loss: 1.2339e-04 - acc: 1.0000 - val_loss: 0.6476 - val_acc: 0.8736
# Epoch 40/100
#  - 1s - loss: 1.2233e-04 - acc: 1.0000 - val_loss: 0.6471 - val_acc: 0.8736
# Epoch 41/100
#  - 1s - loss: 1.2129e-04 - acc: 1.0000 - val_loss: 0.6479 - val_acc: 0.8736
# Epoch 42/100
#  - 1s - loss: 1.2026e-04 - acc: 1.0000 - val_loss: 0.6465 - val_acc: 0.8736
# Epoch 43/100
#  - 1s - loss: 1.1925e-04 - acc: 1.0000 - val_loss: 0.6476 - val_acc: 0.8736
# Epoch 44/100
#  - 1s - loss: 1.1827e-04 - acc: 1.0000 - val_loss: 0.6456 - val_acc: 0.8736
# Epoch 45/100
#  - 1s - loss: 1.1730e-04 - acc: 1.0000 - val_loss: 0.6474 - val_acc: 0.8621
# Epoch 46/100
#  - 1s - loss: 1.1636e-04 - acc: 1.0000 - val_loss: 0.6495 - val_acc: 0.8621
# Epoch 47/100
#  - 1s - loss: 1.1541e-04 - acc: 1.0000 - val_loss: 0.6511 - val_acc: 0.8621
# Epoch 48/100
#  - 1s - loss: 1.1450e-04 - acc: 1.0000 - val_loss: 0.6517 - val_acc: 0.8621
# Epoch 49/100
#  - 1s - loss: 1.1359e-04 - acc: 1.0000 - val_loss: 0.6513 - val_acc: 0.8621
# Epoch 50/100
#  - 1s - loss: 1.1269e-04 - acc: 1.0000 - val_loss: 0.6511 - val_acc: 0.8621
# Epoch 51/100
#  - 1s - loss: 1.1181e-04 - acc: 1.0000 - val_loss: 0.6522 - val_acc: 0.8621
# Epoch 52/100
#  - 1s - loss: 1.1094e-04 - acc: 1.0000 - val_loss: 0.6509 - val_acc: 0.8621
# Epoch 53/100
#  - 1s - loss: 1.1010e-04 - acc: 1.0000 - val_loss: 0.6533 - val_acc: 0.8621
# Epoch 54/100
#  - 1s - loss: 1.0925e-04 - acc: 1.0000 - val_loss: 0.6497 - val_acc: 0.8621
# Epoch 55/100
#  - 1s - loss: 1.0842e-04 - acc: 1.0000 - val_loss: 0.6581 - val_acc: 0.8621
# Epoch 56/100
#  - 1s - loss: 1.0760e-04 - acc: 1.0000 - val_loss: 0.6573 - val_acc: 0.8621
# Epoch 57/100
#  - 1s - loss: 1.0679e-04 - acc: 1.0000 - val_loss: 0.6579 - val_acc: 0.8621
# Epoch 58/100
#  - 1s - loss: 1.0599e-04 - acc: 1.0000 - val_loss: 0.6566 - val_acc: 0.8621
# Epoch 59/100
#  - 1s - loss: 1.0521e-04 - acc: 1.0000 - val_loss: 0.6589 - val_acc: 0.8621
# Epoch 60/100
#  - 1s - loss: 1.0444e-04 - acc: 1.0000 - val_loss: 0.6598 - val_acc: 0.8621
# Epoch 61/100
#  - 1s - loss: 1.0368e-04 - acc: 1.0000 - val_loss: 0.6601 - val_acc: 0.8621
# Epoch 62/100
#  - 1s - loss: 1.0293e-04 - acc: 1.0000 - val_loss: 0.6594 - val_acc: 0.8621
# Epoch 63/100
#  - 1s - loss: 1.0220e-04 - acc: 1.0000 - val_loss: 0.6616 - val_acc: 0.8621
# Epoch 64/100
#  - 1s - loss: 1.0148e-04 - acc: 1.0000 - val_loss: 0.6624 - val_acc: 0.8621
# Epoch 65/100
#  - 1s - loss: 1.0077e-04 - acc: 1.0000 - val_loss: 0.6642 - val_acc: 0.8621
# Epoch 66/100
#  - 1s - loss: 1.0006e-04 - acc: 1.0000 - val_loss: 0.6640 - val_acc: 0.8621
# Epoch 67/100
#  - 1s - loss: 9.9366e-05 - acc: 1.0000 - val_loss: 0.6661 - val_acc: 0.8621
# Epoch 68/100
#  - 1s - loss: 9.8684e-05 - acc: 1.0000 - val_loss: 0.6648 - val_acc: 0.8621
# Epoch 69/100
#  - 1s - loss: 9.8004e-05 - acc: 1.0000 - val_loss: 0.6687 - val_acc: 0.8621
# Epoch 70/100
#  - 1s - loss: 9.7339e-05 - acc: 1.0000 - val_loss: 0.6682 - val_acc: 0.8621
# Epoch 71/100
#  - 1s - loss: 9.6687e-05 - acc: 1.0000 - val_loss: 0.6676 - val_acc: 0.8621
# Epoch 72/100
#  - 1s - loss: 9.6041e-05 - acc: 1.0000 - val_loss: 0.6678 - val_acc: 0.8621
# Epoch 73/100
#  - 1s - loss: 9.5395e-05 - acc: 1.0000 - val_loss: 0.6694 - val_acc: 0.8621
# Epoch 74/100
#  - 1s - loss: 9.4772e-05 - acc: 1.0000 - val_loss: 0.6713 - val_acc: 0.8621
# Epoch 75/100
#  - 1s - loss: 9.4127e-05 - acc: 1.0000 - val_loss: 0.6710 - val_acc: 0.8621
# Epoch 76/100
#  - 1s - loss: 9.3489e-05 - acc: 1.0000 - val_loss: 0.6712 - val_acc: 0.8621
# Epoch 77/100
#  - 1s - loss: 9.2880e-05 - acc: 1.0000 - val_loss: 0.6716 - val_acc: 0.8621
# Epoch 78/100
#  - 1s - loss: 9.2278e-05 - acc: 1.0000 - val_loss: 0.6693 - val_acc: 0.8621
# Epoch 79/100
#  - 1s - loss: 9.1678e-05 - acc: 1.0000 - val_loss: 0.6714 - val_acc: 0.8621
# Epoch 80/100
#  - 1s - loss: 9.1094e-05 - acc: 1.0000 - val_loss: 0.6714 - val_acc: 0.8621
# Epoch 81/100
#  - 1s - loss: 9.0513e-05 - acc: 1.0000 - val_loss: 0.6711 - val_acc: 0.8621
# Epoch 82/100
#  - 1s - loss: 8.9943e-05 - acc: 1.0000 - val_loss: 0.6721 - val_acc: 0.8621
# Epoch 83/100
#  - 1s - loss: 8.9378e-05 - acc: 1.0000 - val_loss: 0.6736 - val_acc: 0.8621
# Epoch 84/100
#  - 1s - loss: 8.8822e-05 - acc: 1.0000 - val_loss: 0.6737 - val_acc: 0.8621
# Epoch 85/100
#  - 1s - loss: 8.8272e-05 - acc: 1.0000 - val_loss: 0.6738 - val_acc: 0.8621
# Epoch 86/100
#  - 1s - loss: 8.7732e-05 - acc: 1.0000 - val_loss: 0.6751 - val_acc: 0.8621
# Epoch 87/100
#  - 1s - loss: 8.7199e-05 - acc: 1.0000 - val_loss: 0.6764 - val_acc: 0.8621
# Epoch 88/100
#  - 1s - loss: 8.6663e-05 - acc: 1.0000 - val_loss: 0.6759 - val_acc: 0.8621
# Epoch 89/100
#  - 1s - loss: 8.6144e-05 - acc: 1.0000 - val_loss: 0.6770 - val_acc: 0.8621
# Epoch 90/100
#  - 1s - loss: 8.5625e-05 - acc: 1.0000 - val_loss: 0.6791 - val_acc: 0.8621
# Epoch 91/100
#  - 1s - loss: 8.5114e-05 - acc: 1.0000 - val_loss: 0.6827 - val_acc: 0.8621
# Epoch 92/100
#  - 1s - loss: 8.4610e-05 - acc: 1.0000 - val_loss: 0.6832 - val_acc: 0.8621
# Epoch 93/100
#  - 1s - loss: 8.4114e-05 - acc: 1.0000 - val_loss: 0.6842 - val_acc: 0.8621
# Epoch 94/100
#  - 1s - loss: 8.3622e-05 - acc: 1.0000 - val_loss: 0.6847 - val_acc: 0.8621
# Epoch 95/100
#  - 1s - loss: 8.3136e-05 - acc: 1.0000 - val_loss: 0.6844 - val_acc: 0.8621
# Epoch 96/100
#  - 1s - loss: 8.2650e-05 - acc: 1.0000 - val_loss: 0.6853 - val_acc: 0.8621
# Epoch 97/100
#  - 1s - loss: 8.2178e-05 - acc: 1.0000 - val_loss: 0.6864 - val_acc: 0.8621
# Epoch 98/100
#  - 1s - loss: 8.1710e-05 - acc: 1.0000 - val_loss: 0.6873 - val_acc: 0.8621
# Epoch 99/100
#  - 1s - loss: 8.1246e-05 - acc: 1.0000 - val_loss: 0.6883 - val_acc: 0.8621
# Epoch 100/100
#  - 1s - loss: 8.0784e-05 - acc: 1.0000 - val_loss: 0.6882 - val_acc: 0.8621

# %%
model.save_weights('Car_5Keys_weights.h5')
